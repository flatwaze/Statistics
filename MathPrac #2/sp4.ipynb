# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy as sc
import scipy.stats as st
import seaborn as sns
import scipy

from numpy.linalg import matrix_power
from numpy.linalg import solve

from statsmodels.distributions.empirical_distribution import ECDF

matplotlib.style.use('ggplot')

# %% [markdown]
# ![image.png](attachment:1527aad5-f41e-4741-83b9-16752e20ad3c.png)

# %%
# H(t) = E(m(t))
def fval(t, a, b):
    S = []
    for i in range(300):
        s = 0
        time = st.gamma(a, scale=b).rvs()
        while time <= t:
            s += 1
            time += st.gamma(a, b).rvs()

        S.append(s)
    return np.mean(S)
        
    
a = 2
b = 2
T = np.linspace(10, 30, 20)
plt.step(T, [fval(t, a, b) for t in T])
plt.plot(T, T/a/b)

# %%
a = 3
b = 2
T = np.linspace(100, 110, 40)
plt.step(T, [fval(t, a, b) for t in T])
plt.plot(T, T/a/b)
